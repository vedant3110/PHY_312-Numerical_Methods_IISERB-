# %% [markdown]
# <a href="https://colab.research.google.com/github/vedant3110/PHY_312-Numerical_Methods_IISERB-/blob/main/Bi_Section_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib numpy scipy

# %% [markdown]
# #Bi-Section method

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
import math as ma

# %% [markdown]
# ####Procedure to do it

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Termination Criteria and Error Estimates

# %% [markdown]
# We must now develop an objective criterion for deciding
# when to terminate the method.We might decide that we should terminate when the error drops below, say, 0.1 percent. This strategy is fl awed because
# the error estimates in the example were based on knowledge of the true root of the
# function.an approximate percent relative error $e_a$:
#
#
#
# $$
#   e_a=\left |\frac{x_r^{new}-x_r^{old}}{x_r^{new}}\right |\cdot100 \%
# $$

# %%
def f(x):
  return ma.log(x)##put function of your choice

# %%
t=np.linspace(0.1,9)
f_x=[]
for i in t:
  f_x.append(f(i))
f_x=np.array(f_x)
plt.plot(t,f_x)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.axhline(y=0, color="black", linestyle=":")

# %% [markdown]
# predicted value of $x_l=0.5$,and $x_u=2$

# %%
x_l=0.6;
x_u=5;
e_a=10;
x_r=(x_l+x_u)/2
while(e_a>0.0001):
  if f(x_l)*f(x_r)>0:
    x_l=x_r
  elif f(x_l)*f(x_r)<0:
    x_u=x_r
  elif f(x_l)*f(x_r)==0:
    break
  x_r_new=(x_l+x_u)/2
  e_a=abs((x_r_new-x_r)/x_r_new)*100
  ##print("lower limit",x_l,"high limit",x_u,"mean",x_r,"new mean",x_r_new6
  print(f"lower limit: {x_l:<15.4f} high limit: {x_u:<15.4f} mean: {x_r:<15.4f} new mean: {x_r_new:<15.4f} error: {e_a:<15.4f}")
  x_r=x_r_new

print(f"\n\nFinal answer:{x_r:.4f}±{e_a:.4f}")
# Out:
# lower limit: 0.6000          high limit: 2.8000          mean: 2.8000          new mean: 1.7000          error: 64.7059
# lower limit: 0.6000          high limit: 1.7000          mean: 1.7000          new mean: 1.1500          error: 47.8261
# lower limit: 0.6000          high limit: 1.1500          mean: 1.1500          new mean: 0.8750          error: 31.4286
# lower limit: 0.8750          high limit: 1.1500          mean: 0.8750          new mean: 1.0125          error: 13.5802
# lower limit: 0.8750          high limit: 1.0125          mean: 1.0125          new mean: 0.9437          error: 7.2848
# lower limit: 0.9437          high limit: 1.0125          mean: 0.9437          new mean: 0.9781          error: 3.5144
# lower limit: 0.9781          high limit: 1.0125          mean: 0.9781          new mean: 0.9953          error: 1.7268
# lower limit: 0.9953          high limit: 1.0125          mean: 0.9953          new mean: 1.0039          error: 0.8560
# ...
